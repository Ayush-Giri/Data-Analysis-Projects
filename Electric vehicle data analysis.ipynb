# %%
import pandas as pd
import numpy as np

# %%
ev = pd.read_csv(filepath_or_buffer="data/Electric_Vehicle_Population_Data.csv")

# %%
ev
# Out:
#         VIN (1-10)     County           City State  Postal Code  Model Year  \
# 0       5YJYGDEE1L       King        Seattle    WA      98122.0        2020
# 1       7SAYGDEE9P  Snohomish        Bothell    WA      98021.0        2023
# 2       5YJSA1E4XK       King        Seattle    WA      98109.0        2019
# 3       5YJSA1E27G       King       Issaquah    WA      98027.0        2016
# 4       5YJYGDEE5M     Kitsap      Suquamish    WA      98392.0        2021
# ...            ...        ...            ...   ...          ...         ...
# 177861  7SAYGDEE3N     Pierce    Bonney Lake    WA      98391.0        2022
# 177862  KM8K23AG1P      Mason        Shelton    WA      98584.0        2023
# 177863  5YJYGDEE6M      Grant         Quincy    WA      98848.0        2021
# 177864  WVGKMPE27M       King  Black Diamond    WA      98010.0        2021
# 177865  5YJ3E1EA8M     Pierce         Tacoma    WA      98422.0        2021
#
# ...

# %%
ev.head()
# Out:
#    VIN (1-10)     County       City State  Postal Code  Model Year   Make  \
# 0  5YJYGDEE1L       King    Seattle    WA      98122.0        2020  TESLA
# 1  7SAYGDEE9P  Snohomish    Bothell    WA      98021.0        2023  TESLA
# 2  5YJSA1E4XK       King    Seattle    WA      98109.0        2019  TESLA
# 3  5YJSA1E27G       King   Issaquah    WA      98027.0        2016  TESLA
# 4  5YJYGDEE5M     Kitsap  Suquamish    WA      98392.0        2021  TESLA
#
#      Model           Electric Vehicle Type  \
# 0  MODEL Y  Battery Electric Vehicle (BEV)
# 1  MODEL Y  Battery Electric Vehicle (BEV)
# 2  MODEL S  Battery Electric Vehicle (BEV)
# 3  MODEL S  Battery Electric Vehicle (BEV)
# 4  MODEL Y  Battery Electric Vehicle (BEV)
#
#    Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0            Clean Alternative Fuel Vehicle Eligible             291
# 1  Eligibility unknown as battery range has not b...               0
# ...

# %%
ev.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 177866 entries, 0 to 177865
# Data columns (total 17 columns):
#  #   Column                                             Non-Null Count   Dtype
# ---  ------                                             --------------   -----
#  0   VIN (1-10)                                         177866 non-null  object
#  1   County                                             177861 non-null  object
#  2   City                                               177861 non-null  object
#  3   State                                              177866 non-null  object
#  4   Postal Code                                        177861 non-null  float64
#  5   Model Year                                         177866 non-null  int64
#  6   Make                                               177866 non-null  object
#  7   Model                                              177866 non-null  object
# ...

# %%
# number of evs registered each year
ev["Model Year"].value_counts().sort_index().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
# seattle is the city with highest number of electric vehicles
ev["City"].value_counts()
# Out:
# Seattle          29447
# Bellevue          8931
# Redmond           6478
# Vancouver         6193
# Bothell           5863
#                  ...
# Plymouth             1
# Tempe                1
# Chapel Hill          1
# Vista                1
# Elizabethtown        1
# Name: City, Length: 723, dtype: int64

# %%
# king county is the county with highest number of electric vehicles
ev["County"].value_counts()
# Out:
# King         92740
# Snohomish    21001
# Pierce       13782
# Clark        10416
# Thurston      6428
#              ...
# Sarpy            1
# Suffolk          1
# Beaufort         1
# Meade            1
# Hardin           1
# Name: County, Length: 196, dtype: int64

# %%
# battery electric vehicles are significantly more than plugin hybrids
ev["Electric Vehicle Type"].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
# these 5 are the most popular ev brands
ev["Make"].value_counts().head(5).plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
# these are the most popular ev models
ev["Model"].value_counts().head(5).plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
ev
# Out:
#         VIN (1-10)     County           City State  Postal Code  Model Year  \
# 0       5YJYGDEE1L       King        Seattle    WA      98122.0        2020
# 1       7SAYGDEE9P  Snohomish        Bothell    WA      98021.0        2023
# 2       5YJSA1E4XK       King        Seattle    WA      98109.0        2019
# 3       5YJSA1E27G       King       Issaquah    WA      98027.0        2016
# 4       5YJYGDEE5M     Kitsap      Suquamish    WA      98392.0        2021
# ...            ...        ...            ...   ...          ...         ...
# 177861  7SAYGDEE3N     Pierce    Bonney Lake    WA      98391.0        2022
# 177862  KM8K23AG1P      Mason        Shelton    WA      98584.0        2023
# 177863  5YJYGDEE6M      Grant         Quincy    WA      98848.0        2021
# 177864  WVGKMPE27M       King  Black Diamond    WA      98010.0        2021
# 177865  5YJ3E1EA8M     Pierce         Tacoma    WA      98422.0        2021
#
# ...

# %%
cropped_df = ev[["Model Year", "Electric Range"]]

# %%
cropped_df.set_index("Model Year", inplace=True)

# %%
cropped_df
# Out:
#             Electric Range
# Model Year
# 2020                   291
# 2023                     0
# 2019                   270
# 2016                   210
# 2021                     0
# ...                    ...
# 2022                     0
# 2023                     0
# 2021                     0
# 2021                     0
# 2021                     0
#
# [177866 rows x 1 columns]

# %%
df_cleaned = cropped_df.groupby(cropped_df.index).max()

# %%
# the elctric range of vehicle is in growing trajectory
df_cleaned.head(len(list(df_cleaned.index)) - 3).plot()
# Out:
# <AxesSubplot:xlabel='Model Year'>
